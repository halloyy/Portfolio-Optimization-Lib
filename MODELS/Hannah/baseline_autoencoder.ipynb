# %% [markdown]
# # End-to-End MLP Workflow for Autoencoder

# %% [markdown]
# ## 1. Colab vs. VSCode
#
# Select the correct kernel before proceeding:
#
# VSCode → .venv/bin/python
#
# Colab → /usr/bin/python (Colab’s environment)

# %%
import os
import sys
import subprocess
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    REPO_URL = "https://github.com/halloyy/Portfolio-Optimization-Lib.git"
    REPO_DIR = "/content/Portfolio-Optimization-Lib"

    os.chdir("/content")

    if os.path.exists(REPO_DIR):
        subprocess.run(["rm", "-rf", REPO_DIR])

    subprocess.run(["git", "clone", REPO_URL], check=True)

    os.chdir(REPO_DIR)

    print("Using Colab")
    subprocess.run([sys.executable, "-m", "pip", "install", "-e", "."], check=True)

    repo_root = Path(REPO_DIR)

else:
    repo_root = Path("/Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib")

    print("Using VSCode")

subprocess.run([sys.executable, "-m", "pip", "install", "-e", str(repo_root)], check=True)
print("repo_root =", repo_root)
# Out:
# Using VSCode
# Obtaining file:///Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pandas>=2.2 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from portfolio-toolkit==0.1.0) (2.3.3)
# Requirement already satisfied: numpy>=1.26 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from portfolio-toolkit==0.1.0) (2.4.4)
# Requirement already satisfied: yfinance>=0.2.54 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from portfolio-toolkit==0.1.0) (1.3.0)
# Requirement already satisfied: bt>=1.1.2 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from portfolio-toolkit==0.1.0) (1.2.0)
# Requirement already satisfied: quantstats>=0.0.64 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from portfolio-toolkit==0.1.0) (0.0.81)
# Requirement already satisfied: mlflow>=2.17 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from portfolio-toolkit==0.1.0) (3.11.1)
# Requirement already satisfied: pyarrow>=17.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from portfolio-toolkit==0.1.0) (23.0.1)
# Requirement already satisfied: ffn>=1.1.2 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from bt>=1.1.2->portfolio-toolkit==0.1.0) (1.1.5)
# Requirement already satisfied: pyprind>=2.11 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from bt>=1.1.2->portfolio-toolkit==0.1.0) (2.11.3)
# Requirement already satisfied: tqdm>=4 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from bt>=1.1.2->portfolio-toolkit==0.1.0) (4.67.3)
# Requirement already satisfied: decorator>=5.0.7 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (5.2.1)
# Requirement already satisfied: matplotlib>=1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (3.10.9)
# Requirement already satisfied: scikit-learn>=0.15 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (1.8.0)
# Requirement already satisfied: scipy>=0.15 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (1.17.1)
# Requirement already satisfied: tabulate>=0.7.5 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (0.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from matplotlib>=1->ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from matplotlib>=1->ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from matplotlib>=1->ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from matplotlib>=1->ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from matplotlib>=1->ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (26.2)
# Requirement already satisfied: pillow>=8 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from matplotlib>=1->ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from matplotlib>=1->ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from matplotlib>=1->ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (2.9.0.post0)
# Requirement already satisfied: mlflow-skinny==3.11.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (3.11.1)
# Requirement already satisfied: mlflow-tracing==3.11.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (3.11.1)
# Requirement already satisfied: Flask-CORS<7 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (6.0.2)
# Requirement already satisfied: Flask<4 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (3.1.3)
# Requirement already satisfied: aiohttp<4 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (3.13.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (1.18.4)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (46.0.7)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (7.1.0)
# Requirement already satisfied: graphene<4 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (3.4.3)
# Requirement already satisfied: gunicorn<26 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (25.3.0)
# Requirement already satisfied: huey<3,>=2.5.4 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (2.6.0)
# Requirement already satisfied: skops<1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (0.14.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow>=2.17->portfolio-toolkit==0.1.0) (2.0.49)
# Requirement already satisfied: cachetools<8,>=5.0.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (7.1.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (8.3.3)
# Requirement already satisfied: cloudpickle<4 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.106.0)
# Requirement already satisfied: fastapi<1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.136.1)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.1.49)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (1.41.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (1.41.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (1.41.1)
# Requirement already satisfied: protobuf<8,>=3.12.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (6.33.6)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (2.13.3)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (1.2.2)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (2.33.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.46.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (1.23.0)
# Requirement already satisfied: Mako in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow>=2.17->portfolio-toolkit==0.1.0) (1.3.12)
# Requirement already satisfied: cffi>=2.0.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from cryptography<47,>=43.0.0->mlflow>=2.17->portfolio-toolkit==0.1.0) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (2.50.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow>=2.17->portfolio-toolkit==0.1.0) (2.6.3)
# Requirement already satisfied: starlette>=0.46.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from Flask<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from Flask<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from Flask<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from Flask<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from Flask<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.1.8)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (5.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.4.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from graphene<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.2.8)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from graphene<4->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.2.0)
# Requirement already satisfied: zipp>=3.20 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.23.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.62b1)
# Requirement already satisfied: pytz>=2020.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from pandas>=2.2->portfolio-toolkit==0.1.0) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from pandas>=2.2->portfolio-toolkit==0.1.0) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (2.46.3)
# Requirement already satisfied: six>=1.5 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=1->ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.13)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (2026.4.22)
# Requirement already satisfied: joblib>=1.3.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from scikit-learn>=0.15->ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from scikit-learn>=0.15->ffn>=1.1.2->bt>=1.1.2->portfolio-toolkit==0.1.0) (3.6.0)
# Requirement already satisfied: prettytable>=3.9 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from skops<1->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.17.0)
# Requirement already satisfied: h11>=0.8 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.16.0)
# Requirement already satisfied: pycparser in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow>=2.17->portfolio-toolkit==0.1.0) (3.0)
# Requirement already satisfied: wcwidth in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from prettytable>=3.9->skops<1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.7.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (0.6.3)
# Requirement already satisfied: seaborn>=0.13.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from quantstats>=0.0.64->portfolio-toolkit==0.1.0) (0.13.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from starlette>=0.46.0->fastapi<1->mlflow-skinny==3.11.1->mlflow>=2.17->portfolio-toolkit==0.1.0) (4.13.0)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from yfinance>=0.2.54->portfolio-toolkit==0.1.0) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from yfinance>=0.2.54->portfolio-toolkit==0.1.0) (4.9.6)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from yfinance>=0.2.54->portfolio-toolkit==0.1.0) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from yfinance>=0.2.54->portfolio-toolkit==0.1.0) (4.0.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from yfinance>=0.2.54->portfolio-toolkit==0.1.0) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.15 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from yfinance>=0.2.54->portfolio-toolkit==0.1.0) (0.15.0)
# Requirement already satisfied: websockets>=13.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from yfinance>=0.2.54->portfolio-toolkit==0.1.0) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.54->portfolio-toolkit==0.1.0) (2.8.3)
# Requirement already satisfied: rich in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from curl_cffi>=0.15->yfinance>=0.2.54->portfolio-toolkit==0.1.0) (15.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from rich->curl_cffi>=0.15->yfinance>=0.2.54->portfolio-toolkit==0.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from rich->curl_cffi>=0.15->yfinance>=0.2.54->portfolio-toolkit==0.1.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance>=0.2.54->portfolio-toolkit==0.1.0) (0.1.2)
# Building wheels for collected packages: portfolio-toolkit
#   Building editable for portfolio-toolkit (pyproject.toml): started
#   Building editable for portfolio-toolkit (pyproject.toml): finished with status 'done'
#   Created wheel for portfolio-toolkit: filename=portfolio_toolkit-0.1.0-0.editable-py3-none-any.whl size=2732 sha256=062f63203d15460f592429082b829cf070a1469363a4723ead07ab2daee098b1
#   Stored in directory: /private/var/folders/fd/x9n5kmb161sc_mrqs099qrv80000gn/T/pip-ephem-wheel-cache-dzm73iq4/wheels/6b/3d/e1/3ca39d3190596d55155324f56d43f41510cd4587a992c9b7fa
# Successfully built portfolio-toolkit
# Installing collected packages: portfolio-toolkit
#   Attempting uninstall: portfolio-toolkit
#     Found existing installation: portfolio-toolkit 0.1.0
#     Uninstalling portfolio-toolkit-0.1.0:
#       Successfully uninstalled portfolio-toolkit-0.1.0
# Successfully installed portfolio-toolkit-0.1.0
# repo_root = /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib

# %% [markdown]
# ## 2. Imports and Configurations

# %%
from pathlib import Path
import numpy as np
import pandas as pd
 
from portfolio_toolkit import (
    build_features,
    build_metrics,
    get_dataset_spec,
    init_mlflow,
    load_prices,
    log_backtest,
    log_portfolio,
    log_predictions,
    make_forward_alpha_target,
    make_forward_realized_vol_target,
    make_forward_return_target,
    slice_split,
    split_dates,
    start_run,
    validate_prediction_frame,
    validate_weights_frame,
    weights_from_predictions_risk_adjusted,
    backtest_weights,
    write_backtest_artifacts,
)

# ---------------------------------------------------------------------
# Basic run configuration.
# ---------------------------------------------------------------------
# repo_root: Where the toolkit config files, cache, MLflow folder, and runs folder live.

# dataset_name: Which shared ticker universe + split rules we want to use.

# horizon: Our prediction horizon in trading days.

# output_dir:Where this notebook will write artifacts like metrics and QuantStats.

repo_root     = Path(repo_root).resolve() if "repo_root" in globals() else Path("../../").resolve()
dataset_name  = "shared_set_1"
model_name    = "autoencoder_mlp_downstream"
horizon       = 5 
output_dir    = repo_root / "runs" / "autoencoder_downstream"
output_dir.mkdir(parents=True, exist_ok=True)
 
# FIX: single source of truth for hyperparameters — used in training AND mlflow logging.
AE_EPOCHS    = 25
MLP_EPOCHS   = 30
BATCH_SIZE   = 1024
LATENT_DIM   = 8 #DIMENSIONS OF THE MIN AUTOENCODER THINGY
LEARNING_RATE = 1e-3
PATIENCE     = 5   # early stopping patience (epochs without val improvement)
 
spec   = get_dataset_spec(dataset_name, repo_root=repo_root)
splits = split_dates(dataset_name, repo_root=repo_root)
 
print("Dataset preset:",       dataset_name)
print("Dataset display name:", spec.name)
print("Tickers modeled:",      len(spec.tickers))
print("Benchmark ticker:",     spec.benchmark_ticker)
print("Train/Val/Test windows:", splits)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 5
#       1 from pathlib import Path
#       2 import numpy as np
#       3 import pandas as pd
#       4
# ----> 5 from portfolio_toolkit import (
#       6     build_features,
#       7     build_metrics,
#       8     get_dataset_spec,
#
# ModuleNotFoundError: No module named 'portfolio_toolkit'

# %% [markdown]
# ## 3. Load Price Data

# %%
prices = load_prices(dataset_name, repo_root=repo_root)

print('Price frame shape:', prices.shape)
print('Date range:', prices['date'].min(), '->', prices['date'].max())
print('Number of unique tickers in price frame:', prices['ticker'].nunique())
display(prices.head())
# Out:
# Price frame shape: (1463605, 8)
# Date range: 2014-01-02 00:00:00 -> 2025-12-31 00:00:00
# Number of unique tickers in price frame: 504
#         date ticker       open       high        low      close  adj_close  \
# 0 2014-01-02      A  40.844063  40.844063  40.164520  40.207439  36.303501
# 1 2014-01-03      A  40.336197  41.022888  40.243206  40.715309  36.762070
# 2 2014-01-06      A  41.058655  41.273247  40.457798  40.515022  36.581226
# 3 2014-01-07      A  40.736767  41.223175  40.722462  41.094421  37.104366
# 4 2014-01-08      A  41.008583  41.874107  40.894135  41.766811  37.711464
#
#     volume
# 0  2678848
# 1  2609647
# 2  2484665
# 3  2045554
# 4  3717981

# %% [markdown]
# ## 4. Base Features

# %%
base_feature_names = [
    'return_5d', 'return_20d',
    'vol_20d',
    'momentum_20d', 'momentum_60d',
    'rsi_14',
    'price_to_sma_20d', 'price_to_sma_50d',
    'volume_zscore_20d',
    'excess_return_20d_vs_spy',
    'intraday_range',
    'beta_20d_spy',
]

base_features = build_features(prices, feature_names=base_feature_names)
print('Base feature frame shape:', base_features.shape)
display(base_features.head())
# Out:
# Base feature frame shape: (1463605, 14)
#         date ticker  return_5d  return_20d  vol_20d  momentum_20d  \
# 0 2014-01-02      A        NaN         NaN      NaN           NaN
# 1 2014-01-03      A        NaN         NaN      NaN           NaN
# 2 2014-01-06      A        NaN         NaN      NaN           NaN
# 3 2014-01-07      A        NaN         NaN      NaN           NaN
# 4 2014-01-08      A        NaN         NaN      NaN           NaN
#
#    momentum_60d  rsi_14  price_to_sma_20d  price_to_sma_50d  \
# 0           NaN     NaN               NaN               NaN
# 1           NaN     NaN               NaN               NaN
# 2           NaN     NaN               NaN               NaN
# 3           NaN     NaN               NaN               NaN
# 4           NaN     NaN               NaN               NaN
#
#    volume_zscore_20d  excess_return_20d_vs_spy  intraday_range  beta_20d_spy
# 0                NaN                       NaN        0.016901           NaN
# 1                NaN                       NaN        0.019150           NaN
# 2                NaN                       NaN        0.020127           NaN
# 3                NaN                       NaN        0.012184           NaN
# 4                NaN                       NaN        0.023463           NaN

# %% [markdown]
# ## 5. Custom Features
#
# Below we add a few simple handcrafted features:
#
# - `mom_vol_ratio`
#   A momentum-to-volatility ratio. This is a quick-and-dirty risk-adjusted trend signal.
# - `trend_spread`
#   The gap between short-term and medium-term trend distance.
# - `quality_signal`
#   A simple benchmark-relative momentum signal penalized by volatility.
# - `range_volume_interaction`
#   A rough interaction term between price range expansion and unusual volume.

# %%
frame = base_features.copy()

# Add a very small constant anywhere we divide so we do not create infinities.
eps = 1e-6

frame['mom_vol_ratio'] = frame['momentum_20d'] / (frame['vol_20d'].abs() + eps)
frame['trend_spread'] = frame['price_to_sma_20d'] - frame['price_to_sma_50d']
frame['quality_signal'] = frame['excess_return_20d_vs_spy'] - 0.5 * frame['vol_20d']
frame['range_volume_interaction'] = frame['intraday_range'] * frame['volume_zscore_20d']

custom_feature_names = [
    'mom_vol_ratio',
    'trend_spread',
    'quality_signal',
    'range_volume_interaction',
]

all_feature_names = base_feature_names + custom_feature_names
display(frame.loc[:, ['date', 'ticker'] + custom_feature_names].head())
# Out:
#         date ticker  mom_vol_ratio  trend_spread  quality_signal  \
# 0 2014-01-02      A            NaN           NaN             NaN
# 1 2014-01-03      A            NaN           NaN             NaN
# 2 2014-01-06      A            NaN           NaN             NaN
# 3 2014-01-07      A            NaN           NaN             NaN
# 4 2014-01-08      A            NaN           NaN             NaN
#
#    range_volume_interaction
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %% [markdown]
# ## 6. Build Targets
#
# `expected_return`: future return over next 'horizon' days
#
# `expected_alpha`: return relative to a benchmark (SPY)
#
# `expected_volatility`: realized volatility over the next window
#
# In plain English:
# “What should the model learn to predict?”

# %%
return_targets = make_forward_return_target(prices, horizon=horizon)
alpha_targets = make_forward_alpha_target(prices, horizon=horizon)
vol_targets = make_forward_realized_vol_target(prices, window=horizon)

target_frame = frame.merge(return_targets, on=['date', 'ticker'], how='left')
target_frame = target_frame.merge(alpha_targets, on=['date', 'ticker'], how='left')
target_frame = target_frame.merge(vol_targets, on=['date', 'ticker'], how='left')

# Drop rows only after all features and targets are assembled.
# This is the usual notebook pattern because long-window features and forward targets
# naturally create missing values near the beginning and end of each ticker history.
target_frame = target_frame.replace([np.inf, -np.inf], np.nan).dropna().reset_index(drop=True)

return_target_col = f'forward_return_{horizon}d'
alpha_target_col = f'forward_alpha_{horizon}d_vs_spy'
vol_target_col = f'forward_realized_vol_{horizon}d'

print('Modeling frame shape after dropping nulls:', target_frame.shape)
display(target_frame.head())
# Out:
# Modeling frame shape after dropping nulls: (1429805, 21)
#         date ticker  return_5d  return_20d   vol_20d  momentum_20d  \
# 0 2014-03-31      A   0.011944   -0.013930  0.012208     -0.013930
# 1 2014-04-01      A   0.021755   -0.024576  0.011547     -0.024576
# 2 2014-04-02      A   0.027189   -0.019550  0.011636     -0.019550
# 3 2014-04-03      A   0.034924   -0.036924  0.010905     -0.036924
# 4 2014-04-04      A   0.016091   -0.048785  0.011450     -0.048785
#
#    momentum_60d     rsi_14  price_to_sma_20d  price_to_sma_50d  ...  \
# 0     -0.005159  42.943065         -0.009415         -0.025475  ...
# 1     -0.009839  44.927420         -0.000364         -0.016316  ...
# 2      0.000530  56.833207          0.006143         -0.009460  ...
# 3     -0.014796  60.247422          0.006840         -0.009183  ...
# 4     -0.048296  48.183087         -0.008970         -0.025884  ...
#
#    excess_return_20d_vs_spy  intraday_range  beta_20d_spy  mom_vol_ratio  \
# 0                 -0.029366        0.026466      1.670219      -1.140983
# 1                 -0.032577        0.013840      1.698961      -2.128089
# 2                 -0.030008        0.008823      1.707912      -1.680024
# 3                 -0.043739        0.015371      1.650538      -3.385684
# 4                 -0.043275        0.030412      1.610599      -4.260380
#
#    trend_spread  quality_signal  range_volume_interaction  forward_return_5d  \
# 0      0.016060       -0.035470                 -0.007275          -0.028076
# 1      0.015952       -0.038351                 -0.004805          -0.030163
# 2      0.015603       -0.035826                 -0.004240          -0.017037
# 3      0.016023       -0.049192                 -0.014667          -0.042741
# 4      0.016914       -0.049000                  0.011554          -0.048088
#
#    forward_alpha_5d_vs_spy  forward_realized_vol_5d
# 0                -0.013799                 0.194403
# 1                -0.013430                 0.187197
# 2                -0.007560                 0.241530
# 3                -0.013743                 0.283489
# 4                -0.021854                 0.294818
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 5. Shared Train / Validation / Test Splits And Feature Scaling
#
# This section does two very important things:
#
# 1. Uses the repo's shared split functions so the notebook respects the official date windows.
# 2. Standardizes features **using only the training split statistics**.
#
# That second part matters a lot.
#
# We do **not** want to normalize using future information from validation or test rows. So we compute mean and standard deviation from the train split only, then reuse those values everywhere else.
#
# In plain English:
# “Learn on past data, test on future data without cheating.”

# %%
train = slice_split(target_frame, dataset_name, "train", repo_root=repo_root)
val   = slice_split(target_frame, dataset_name, "val",   repo_root=repo_root)
test  = slice_split(target_frame, dataset_name, "test",  repo_root=repo_root)
 
print("Train rows:", len(train))
print("Val rows:",   len(val))
print("Test rows:",  len(test))
 
# Standardize using training-set statistics only.
train_means = train[all_feature_names].mean()
train_stds  = train[all_feature_names].std(ddof=0).replace(0.0, 1.0)
 
def standardize(feature_frame: pd.DataFrame) -> np.ndarray:
    return ((feature_frame[all_feature_names] - train_means) / train_stds).to_numpy(dtype=float)
 
X_train = standardize(train)
X_val   = standardize(val)
X_test  = standardize(test)
 
y_train_return = train[return_target_col].to_numpy(dtype=float)
y_val_return   = val[return_target_col].to_numpy(dtype=float)
y_test_return  = test[return_target_col].to_numpy(dtype=float)
 
y_train_alpha  = train[alpha_target_col].to_numpy(dtype=float)
y_val_alpha    = val[alpha_target_col].to_numpy(dtype=float)
 
y_train_vol    = train[vol_target_col].to_numpy(dtype=float)
y_val_vol      = val[vol_target_col].to_numpy(dtype=float)
 
print("X_train shape:", X_train.shape)
print("Feature count:", X_train.shape[1])
# Out:
# Train rows: 683378
# Val rows: 247827
# Test rows: 498600
# X_train shape: (683378, 16)
# Feature count: 16

# %% [markdown]
# ## 6. Basic MLP Class
#
# 64 -> 32 -> 16 -> 8 -> 16 -> 32 -> 64

# %%
#Define models
import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader
 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
 
 
class Autoencoder(nn.Module):
    def __init__(self, input_dim):
        super().__init__()

        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, LATENT_DIM),
        )

        self.decoder = nn.Sequential(
            nn.Linear(LATENT_DIM, 16),
            nn.ReLU(),
            nn.Linear(16, 32),
            nn.ReLU(),
            nn.Linear(32, 64),
            nn.ReLU(),
            nn.Linear(64, input_dim),
        )

    def forward(self, x):
        return self.decoder(self.encoder(x))
 
 
class TorchMLPRegressor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
        )
 
    def forward(self, x):
        return self.net(x)
# Out:
# Using device: cpu

# %% [markdown]
# ## 7. Train Three Small MLPs
#
# We are using the same feature matrix to train three related regressors:
#
# - return model
# - alpha model
# - volatility model
#
# This is a very common pattern in research projects:
#
# - one common feature pipeline
# - multiple prediction heads or target-specific models
#
# The code below wraps the repeated steps in a helper function so the notebook stays readable.
#
# In plain English:
# “Teach the model what patterns lead to future returns.”

# %%
#train helpers
def train_autoencoder(X_tr, X_va):
    """Trains the autoencoder with minibatching and early stopping."""
    model = Autoencoder(input_dim=X_tr.shape[1]).to(device) 
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    loss_fn   = nn.MSELoss()
 
    X_tr_t = torch.tensor(X_tr, dtype=torch.float32).to(device)
    X_va_t = torch.tensor(X_va, dtype=torch.float32).to(device)
 
    loader = DataLoader(
        TensorDataset(X_tr_t, X_tr_t),
        batch_size=BATCH_SIZE,
        shuffle=True,
    )
 
    best_val_loss = float("inf")
    patience_counter = 0
    best_state = {k: v.clone() for k, v in model.state_dict().items()}
 
    for epoch in range(AE_EPOCHS):
        model.train()
        epoch_loss = 0.0
        for xb, _ in loader:
            optimizer.zero_grad()
            loss = loss_fn(model(xb), xb)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item() * len(xb)
        epoch_loss /= len(X_tr)
 
        model.eval()
        with torch.no_grad():
            val_loss = loss_fn(model(X_va_t), X_va_t).item()
 
        print(f"AE  Epoch {epoch+1:3d}/{AE_EPOCHS} | train loss: {epoch_loss:.6f} | val loss: {val_loss:.6f}")
 
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = {k: v.clone() for k, v in model.state_dict().items()}
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= PATIENCE:
                print(f"  Early stopping at epoch {epoch+1} (no val improvement for {PATIENCE} epochs).")
                break
 
    model.load_state_dict(best_state)
    return model
 
 
def train_predictor(X_tr, y_tr, X_va, y_va, label="MLP"):
    """Trains a downstream MLP predictor with minibatching and early stopping."""
    model     = TorchMLPRegressor(input_dim=X_tr.shape[1]).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    loss_fn   = nn.MSELoss()
 
    X_tr_t = torch.tensor(X_tr, dtype=torch.float32).to(device)
    y_tr_t = torch.tensor(y_tr.reshape(-1, 1), dtype=torch.float32).to(device)
    X_va_t = torch.tensor(X_va, dtype=torch.float32).to(device)
    y_va_np = y_va.reshape(-1)
 
    loader = DataLoader(
        TensorDataset(X_tr_t, y_tr_t),
        batch_size=BATCH_SIZE,
        shuffle=True,
    )
 
    best_val_loss = float("inf")
    patience_counter = 0
    best_state = {k: v.clone() for k, v in model.state_dict().items()}
 
    for epoch in range(MLP_EPOCHS):
        model.train()
        for xb, yb in loader:
            optimizer.zero_grad()
            loss_fn(model(xb), yb).backward()
            optimizer.step()
 
        model.eval()
        with torch.no_grad():
            val_pred = model(X_va_t).cpu().numpy().reshape(-1)
        val_loss = np.mean((val_pred - y_va_np) ** 2)
 
        print(f"{label} Epoch {epoch+1:3d}/{MLP_EPOCHS} | val MSE: {val_loss:.6f}")
 
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_state = {k: v.clone() for k, v in model.state_dict().items()}
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= PATIENCE:
                print(f"  Early stopping at epoch {epoch+1}.")
                break
 
    model.load_state_dict(best_state)
    return model
 
 
def encode(ae_model, X):
    """Extract latent representations from a trained autoencoder encoder."""
    ae_model.eval()
    with torch.no_grad():
        return ae_model.encoder(torch.tensor(X, dtype=torch.float32).to(device)).cpu().numpy()
 
 
def predict(model, X):
    """Run inference with a trained predictor."""
    model.eval()
    with torch.no_grad():
        return model(torch.tensor(X, dtype=torch.float32).to(device)).cpu().numpy().reshape(-1)
    
#train autoencoder
autoencoder = train_autoencoder(X_train, X_val)
 
Z_train = encode(autoencoder, X_train)
Z_val   = encode(autoencoder, X_val)
Z_test  = encode(autoencoder, X_test)


#train downstream predictors
print("--- Training return predictor ---")
return_model = train_predictor(Z_train, y_train_return, Z_val, y_val_return, label="Return MLP")
 
print("\n--- Training alpha predictor ---")
alpha_model  = train_predictor(Z_train, y_train_alpha, Z_val, y_val_alpha, label="Alpha  MLP")

print("\n--- Training volatility predictor ---")
vol_model = train_predictor(Z_train, y_train_vol, Z_val, y_val_vol, label="Vol MLP")
# Out:
# AE  Epoch   1/25 | train loss: 0.290903 | val loss: 0.306059
# AE  Epoch   2/25 | train loss: 0.098839 | val loss: 0.166736
# AE  Epoch   3/25 | train loss: 0.063194 | val loss: 0.155189
# AE  Epoch   4/25 | train loss: 0.046979 | val loss: 0.120906
# AE  Epoch   5/25 | train loss: 0.042132 | val loss: 0.116805
# AE  Epoch   6/25 | train loss: 0.033503 | val loss: 0.109230
# AE  Epoch   7/25 | train loss: 0.028544 | val loss: 0.083747
# AE  Epoch   8/25 | train loss: 0.027381 | val loss: 0.080176
# AE  Epoch   9/25 | train loss: 0.026554 | val loss: 0.075480
# AE  Epoch  10/25 | train loss: 0.025794 | val loss: 0.070888
# AE  Epoch  11/25 | train loss: 0.025009 | val loss: 0.069760
# AE  Epoch  12/25 | train loss: 0.024549 | val loss: 0.067962
# AE  Epoch  13/25 | train loss: 0.024166 | val loss: 0.068030
# AE  Epoch  14/25 | train loss: 0.023852 | val loss: 0.066778
# AE  Epoch  15/25 | train loss: 0.023573 | val loss: 0.069197
# AE  Epoch  16/25 | train loss: 0.023181 | val loss: 0.067450
# AE  Epoch  17/25 | train loss: 0.022947 | val loss: 0.066413
# AE  Epoch  18/25 | train loss: 0.022630 | val loss: 0.065707
# AE  Epoch  19/25 | train loss: 0.022310 | val loss: 0.063983
# AE  Epoch  20/25 | train loss: 0.022060 | val loss: 0.062115
# AE  Epoch  21/25 | train loss: 0.021818 | val loss: 0.062336
# AE  Epoch  22/25 | train loss: 0.021562 | val loss: 0.062714
# AE  Epoch  23/25 | train loss: 0.021354 | val loss: 0.060800
# AE  Epoch  24/25 | train loss: 0.021175 | val loss: 0.060128
# AE  Epoch  25/25 | train loss: 0.020996 | val loss: 0.058290
# --- Training return predictor ---
# Return MLP Epoch   1/30 | val MSE: 0.003575
# Return MLP Epoch   2/30 | val MSE: 0.003509
# Return MLP Epoch   3/30 | val MSE: 0.003470
# Return MLP Epoch   4/30 | val MSE: 0.003502
# Return MLP Epoch   5/30 | val MSE: 0.003537
# Return MLP Epoch   6/30 | val MSE: 0.003462
# Return MLP Epoch   7/30 | val MSE: 0.003489
# Return MLP Epoch   8/30 | val MSE: 0.003545
# Return MLP Epoch   9/30 | val MSE: 0.003639
# Return MLP Epoch  10/30 | val MSE: 0.003657
# Return MLP Epoch  11/30 | val MSE: 0.003560
#   Early stopping at epoch 11.
#
# --- Training alpha predictor ---
# Alpha  MLP Epoch   1/30 | val MSE: 0.002335
# Alpha  MLP Epoch   2/30 | val MSE: 0.002263
# Alpha  MLP Epoch   3/30 | val MSE: 0.002270
# Alpha  MLP Epoch   4/30 | val MSE: 0.002323
# Alpha  MLP Epoch   5/30 | val MSE: 0.002287
# Alpha  MLP Epoch   6/30 | val MSE: 0.002253
# Alpha  MLP Epoch   7/30 | val MSE: 0.002249
# Alpha  MLP Epoch   8/30 | val MSE: 0.002259
# Alpha  MLP Epoch   9/30 | val MSE: 0.002277
# Alpha  MLP Epoch  10/30 | val MSE: 0.002318
# Alpha  MLP Epoch  11/30 | val MSE: 0.002266
# Alpha  MLP Epoch  12/30 | val MSE: 0.002251
#   Early stopping at epoch 12.
#
# --- Training volatility predictor ---
# Vol MLP Epoch   1/30 | val MSE: 0.040954
# Vol MLP Epoch   2/30 | val MSE: 0.040596
# Vol MLP Epoch   3/30 | val MSE: 0.044780
# Vol MLP Epoch   4/30 | val MSE: 0.039470
# Vol MLP Epoch   5/30 | val MSE: 0.049091
# Vol MLP Epoch   6/30 | val MSE: 0.039508
# Vol MLP Epoch   7/30 | val MSE: 0.038434
# Vol MLP Epoch   8/30 | val MSE: 0.042369
# Vol MLP Epoch   9/30 | val MSE: 0.045349
# Vol MLP Epoch  10/30 | val MSE: 0.041137
# Vol MLP Epoch  11/30 | val MSE: 0.045266
# Vol MLP Epoch  12/30 | val MSE: 0.041714
#   Early stopping at epoch 12.

# %% [markdown]
# ## 8. Create The Standardized Prediction Table
#
# Now we convert raw model outputs into the shared prediction contract used by the rest of the toolkit.
#
# Required columns:
#
# - `date`
# - `ticker`
# - `horizon`
# - `expected_return`
#
# Optional columns we will also populate:
#
# - `expected_alpha`
# - `expected_volatility`
# - `uncertainty`
#
# For this notebook, `uncertainty` is just a simple constant based on validation RMSE for the return model. That is not a sophisticated uncertainty estimate. It is only here to demonstrate where that information would live in the shared schema.
#
# In plain English:
# “For each stock, what do we think will happen next?”

# %%
# --- Create a mask to filter out benchmark ticker ---
# SPY is used for alpha/comparison calculations, not for trading predictions
non_benchmark_mask = test["ticker"] != spec.benchmark_ticker
test_no_benchmark = test[non_benchmark_mask].reset_index(drop=True)
Z_test_no_benchmark = Z_test[non_benchmark_mask.values]

# --- Predict return ---
test_return_pred = predict(return_model, Z_test_no_benchmark)

# --- Predict alpha ---
test_alpha_pred = predict(alpha_model, Z_test_no_benchmark)

# --- Predict volatility ---
test_vol_pred = predict(vol_model, Z_test_no_benchmark)
test_vol_pred = np.clip(test_vol_pred, 1e-4, None)

def print_stats(name, arr):
    print(f"{name}:")
    print(f"  mean: {arr.mean():.4f}")
    print(f"  std:  {arr.std():.4f}")
    print(f"  min:  {arr.min():.4f}")
    print(f"  max:  {arr.max():.4f}")

print_stats("Return", test_return_pred)
print_stats("Alpha", test_alpha_pred)
print_stats("Vol", test_vol_pred)

#All predictions
 
predictions = test_no_benchmark.loc[:, ["date", "ticker"]].copy()
predictions["horizon"]             = horizon
predictions["expected_return"]     = test_return_pred
predictions["expected_alpha"]      = test_alpha_pred
predictions["expected_volatility"] = test_vol_pred
predictions["uncertainty"]         = np.abs(test_return_pred - test_return_pred.mean())
 
predictions = validate_prediction_frame(
    predictions,
    dataset_name=dataset_name,
    horizon=horizon,
    repo_root=repo_root,
)
display(predictions.head())
# Out:
# Return:
#   mean: 0.0030
#   std:  0.0043
#   min:  -0.0989
#   max:  0.1971
# Alpha:
#   mean: 0.0025
#   std:  0.0033
#   min:  -0.0837
#   max:  0.1823
# Vol:
#   mean: 0.2333
#   std:  0.0933
#   min:  0.0724
#   max:  3.3137
#         date ticker  horizon  expected_return  expected_alpha  \
# 0 2022-01-03      A        5         0.001576        0.001814
# 1 2022-01-03   AAPL        5        -0.000168       -0.000647
# 2 2022-01-03   ABBV        5        -0.003670       -0.000707
# 3 2022-01-03   ABNB        5         0.004219        0.005389
# 4 2022-01-03    ABT        5         0.000216        0.000594
#
#    expected_volatility  uncertainty
# 0             0.218666     0.001384
# 1             0.233802     0.003127
# 2             0.139668     0.006630
# 3             0.314862     0.001260
# 4             0.179411     0.002743

# %% [markdown]
# ## 9. Portfolio Construction and Validation
#
# The toolkit separates forecasting from portfolio construction.
#
# Here we use the built-in `weights_from_predictions_risk_adjusted(...)` helper.
#
# What it does:
#
# - uses `expected_return / expected_volatility` as the score
# - keeps the allocation long-only
# - normalizes the scores so each row sums to `1.0`
# - returns a `PortfolioWeights` object
#
# In plain English:
# “Use predictions to decide how to allocate money.”

# %%
portfolio = weights_from_predictions_risk_adjusted(predictions, dataset_name=dataset_name, strategy_name=model_name)
validated_weights = validate_weights_frame(portfolio.weights, dataset_name=dataset_name, repo_root=repo_root)

print("Strategy name:",        portfolio.strategy_name)
print("Weights frame shape:",  validated_weights.shape)
display(validated_weights.head())
# Out:
# Strategy name: autoencoder_mlp_downstream
# Weights frame shape: (998, 502)
#                    A      AAPL  ABBV      ABNB       ABT      ACGL       ACN  \
# date
# 2022-01-03  0.002390  0.000000   0.0  0.004445  0.000399  0.000000  0.001818
# 2022-01-04  0.004451  0.000000   0.0  0.003026  0.000858  0.000000  0.002618
# 2022-01-05  0.003985  0.001753   0.0  0.002846  0.002713  0.001719  0.002899
# 2022-01-06  0.003078  0.001007   0.0  0.002937  0.002759  0.000745  0.004841
# 2022-01-07  0.004152  0.000801   0.0  0.002233  0.002883  0.000000  0.005455
#
#                 ADBE       ADI       ADM  ...        WY      WYNN       XEL  \
# date                                      ...
# 2022-01-03  0.006075  0.000465  0.000000  ...  0.000435  0.004569  0.000479
# 2022-01-04  0.007276  0.000162  0.000139  ...  0.000000  0.004275  0.000190
# 2022-01-05  0.004858  0.000872  0.001541  ...  0.002191  0.003689  0.002579
# 2022-01-06  0.004745  0.000000  0.002554  ...  0.001841  0.003046  0.002730
# 2022-01-07  0.004648  0.000000  0.000409  ...  0.001479  0.003376  0.000752
#
#                  XOM       XYL       XYZ       YUM       ZBH      ZBRA  \
# date
# 2022-01-03  0.000000  0.003669  0.007145  0.000923  0.004817  0.001160
# 2022-01-04  0.000000  0.003701  0.006893  0.000000  0.005773  0.000000
# 2022-01-05  0.000000  0.001877  0.004341  0.001246  0.001862  0.001369
# 2022-01-06  0.000676  0.002404  0.003858  0.001090  0.002805  0.001669
# 2022-01-07  0.001369  0.002498  0.004799  0.000865  0.001751  0.002359
#
#                  ZTS
# date
# 2022-01-03  0.000371
# 2022-01-04  0.002999
# 2022-01-05  0.004320
# 2022-01-06  0.004379
# 2022-01-07  0.004934
#
# [5 rows x 502 columns]

# %% [markdown]
# ## 10. Run Backtest

# %%
row_sums = validated_weights.sum(axis=1)
print("Row sum min/max:", row_sums.min(), row_sums.max()) #Should be about 1.0 for all rows

result       = backtest_weights(dataset_name, portfolio, repo_root=repo_root)
metrics      = build_metrics(result)
artifact_paths = write_backtest_artifacts(result, output_dir)
 
metrics_table = (
    pd.DataFrame([{"metric": k, "value": v} for k, v in sorted(metrics.items())])
    .sort_values("metric")
    .reset_index(drop=True)
)
display(metrics_table)
print("QuantStats report:", artifact_paths["quantstats_report"])
# Out:
# Row sum min/max: 0.9999998673829396 1.0000001353728294
#                                metric        value
# 0   annual_excess_return_vs_benchmark    -0.073718
# 1                       annual_return     0.034594
# 2                   annual_volatility     0.185443
# 3                    average_turnover     0.170140
# 4             benchmark_annual_return     0.108312
# 5         benchmark_annual_volatility     0.179691
# 6              benchmark_max_drawdown    -0.244964
# 7                    benchmark_sharpe     0.602767
# 8              benchmark_total_return     0.507582
# 9                              calmar     0.140425
# 10            evaluation_trading_days  1003.000000
# 11                   evaluation_years     3.991786
# 12         excess_return_vs_benchmark    -0.362178
# 13                       max_drawdown    -0.246352
# 14                             sharpe     0.186548
# 15                sharpe_vs_benchmark    -0.416219
# 16                            sortino     0.272985
# 17                       total_return     0.145404
# QuantStats report: /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/runs/autoencoder_downstream/quantstats.html

# %% [markdown]
# ## 11. Log Run to MLflow

# %%
# Colab-only: connect this runtime to your tailnet in userspace mode.
# Store TS_AUTHKEY in Colab Secrets, not inline in the notebook.
import os

# !curl -fsSL https://tailscale.com/install.sh | sh
# !nohup tailscaled \
    --tun=userspace-networking \
    --socks5-server=127.0.0.1:1055 \
    --outbound-http-proxy-listen=127.0.0.1:1055 \
    >/tmp/tailscaled.log 2>&1 &

# !tailscale up --authkey="tskey-auth-kEJuM1Xyoz11CNTRL-Ju18hfrfLCfjXQ7ECoEFCfJRiSyNjsnrY" --hostname="colab-mlflow" --reset

os.environ["HTTP_PROXY"] = "http://127.0.0.1:1055"
os.environ["HTTPS_PROXY"] = "http://127.0.0.1:1055"
os.environ["NO_PROXY"] = "127.0.0.1,localhost"

print("Tailscale proxy configured for this Colab runtime.")
# Out:
# Installing Tailscale for macos 26.3, using method appstore
# + open https://apps.apple.com/us/app/tailscale/id1475387142
# + set +x
# Installation complete! Log in to start using Tailscale by running:
#
# sudo tailscale up
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[13], line 6
#       2 # Store TS_AUTHKEY in Colab Secrets, not inline in the notebook.
#       3 import os
#       4
#       5 get_ipython().system('curl -fsSL https://tailscale.com/install.sh | sh')
# ----> 6 get_ipython().system('nohup tailscaled      --tun=userspace-networking      --socks5-server=127.0.0.1:1055      --outbound-http-proxy-listen=127.0.0.1:1055      >/tmp/tailscaled.log 2>&1 &')
#       7
#       8 get_ipython().system('tailscale up --authkey="tskey-auth-kEJuM1Xyoz11CNTRL-Ju18hfrfLCfjXQ7ECoEFCfJRiSyNjsnrY" --hostname="colab-mlflow" --reset')
#       9
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py:772, in ZMQInteractiveShell.system_piped(self, cmd)
#     765 if cmd.rstrip().endswith("&"):
#     766     # this is *far* from a rigorous test
#     767     # We do not support backgrounding processes because we either use
#     768     # pexpect or pipes to read from.  Users can always just call
#     769     # os.system() or use ip.system=ip.system_raw
#     770     # if they really want a background process.
#     771     msg = "Background processes not supported."
# --> 772     raise OSError(msg)
#     774 # we explicitly do NOT return the subprocess status code, because
#     775 # a non-None value would trigger :func:`sys.displayhook` calls.
#     776 # Instead, we store the exit_code in user_ns.
#     777 # Also, protect system call from UNC paths on Windows here too
#     778 # as is done in InteractiveShell.system_raw
#     779 if sys.platform == "win32":
#
# OSError: Background processes not supported.

# %%
mlflow_layout = init_mlflow(repo_root)
print("MLflow tracking URI:", mlflow_layout["tracking_uri"])
 
with start_run(
    run_name="Hannah_model_data1", #RUN NAME CHANGE HERE
    dataset_name=dataset_name,
    tags={
        "workflow":           "autoencoder_downstream",
        "model_family":       "autoencoder",
        "prediction_horizon": str(horizon),
    },
    repo_root=repo_root,
):
    import mlflow
 
    mlflow.log_params({
        "model_name":          model_name,
        "dataset_name":        dataset_name,
        "horizon":             horizon,
        "feature_count":       len(all_feature_names),
        "base_feature_list":   ",".join(base_feature_names),
        "custom_feature_list": ",".join(custom_feature_names),
        "latent_dim":          LATENT_DIM,
        "ae_epochs":           AE_EPOCHS,       
        "mlp_epochs":          MLP_EPOCHS,        
        "batch_size":          BATCH_SIZE,
        "learning_rate":       LEARNING_RATE,
        "early_stopping_patience": PATIENCE,
        "ae_hidden_dims":      "64",
        "mlp_hidden_dims":     "32",
        "portfolio_builder":   "weights_from_predictions_risk_adjusted",
        'random_seed': 99,
        "cost_bps":            spec.cost_bps,
    })
 
    log_predictions(predictions)
    log_portfolio(portfolio)
    log_backtest(result)
    print("MLflow logging complete.")
# Out:
# MLflow tracking URI: https://adams-macbook-pro.tail5ddc35.ts.net
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 mlflow_layout = init_mlflow(repo_root)
#       2 print("MLflow tracking URI:", mlflow_layout["tracking_uri"])
#       3
# ----> 4 with start_run(
#       5     run_name="Hannah_model_data1", #RUN NAME CHANGE HERE
#       6     dataset_name=dataset_name,
#       7     tags={
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/src/portfolio_toolkit/tracking.py:114, in start_run(run_name, dataset_name, tags, repo_root)
#     112 mlflow.set_tracking_uri(layout["tracking_uri"])
#     113 experiment_name = f"{settings.experiment_prefix}_{dataset_id}"
# --> 114 experiment_id = _get_or_create_experiment(experiment_name, artifact_root)
#     115 with mlflow.start_run(experiment_id=experiment_id, run_name=run_name) as run:
#     116     merged_tags = {"dataset_name": dataset_id, **(tags or {})}
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/src/portfolio_toolkit/tracking.py:88, in _get_or_create_experiment(experiment_name, artifact_root)
#      87 def _get_or_create_experiment(experiment_name: str, artifact_root: Path | None) -> str:
# ---> 88     existing = mlflow.get_experiment_by_name(experiment_name)
#      89     if existing is not None:
#      90         return existing.experiment_id
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/mlflow/tracking/fluent.py:2166, in get_experiment_by_name(name)
#    2132 def get_experiment_by_name(name: str) -> Experiment | None:
#    2133     """
#    2134     Retrieve an experiment by experiment name from the backend store
#    2135
#    (...)   2164         Creation timestamp: 1662004217511
#    2165     """
# -> 2166     return MlflowClient().get_experiment_by_name(name)
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/mlflow/tracking/client.py:2035, in MlflowClient.get_experiment_by_name(self, name)
#    2003 def get_experiment_by_name(self, name: str) -> Experiment | None:
#    2004     """Retrieve an experiment by experiment name from the backend store
#    2005
#    2006     Args:
#    (...)   2033         Lifecycle_stage: active
#    2034     """
# -> 2035     return self._tracking_client.get_experiment_by_name(name)
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:283, in TrackingServiceClient.get_experiment_by_name(self, name)
#     275 def get_experiment_by_name(self, name):
#     276     """
#     277     Args:
#     278         name: The experiment name.
#    (...)    281         :py:class:`mlflow.entities.Experiment`
#     282     """
# --> 283     return self.store.get_experiment_by_name(name)
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:1120, in RestStore.get_experiment_by_name(self, experiment_name)
#    1118 try:
#    1119     req_body = message_to_json(GetExperimentByName(experiment_name=experiment_name))
# -> 1120     response_proto = self._call_endpoint(GetExperimentByName, req_body)
#    1121     return Experiment.from_proto(response_proto.experiment)
#    1122 except MlflowException as e:
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/mlflow/store/tracking/rest_store.py:243, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     241     endpoint, method = method_to_info[api]
#     242 response_proto = response_proto or api.Response()
# --> 243 return call_endpoint(
#     244     self.get_host_creds(),
#     245     endpoint,
#     246     method,
#     247     json_body,
#     248     response_proto,
#     249     retry_timeout_seconds=retry_timeout_seconds,
#     250 )
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:645, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds, expected_status)
#     643 if method == "GET":
#     644     call_kwargs["params"] = json_body
# --> 645     response = http_request(**call_kwargs)
#     646 else:
#     647     call_kwargs["json"] = json_body
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:278, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, retry_timeout_seconds, **kwargs)
#     275     kwargs["auth"] = fetch_auth(host_creds.auth)
#     277 try:
# --> 278     return _get_http_response_with_retries(
#     279         method,
#     280         url,
#     281         max_retries,
#     282         backoff_factor,
#     283         backoff_jitter,
#     284         retry_codes,
#     285         raise_on_status,
#     286         headers=headers,
#     287         verify=host_creds.verify,
#     288         timeout=timeout,
#     289         respect_retry_after_header=respect_retry_after_header,
#     290         **kwargs,
#     291     )
#     292 except requests.exceptions.Timeout as to:
#     293     raise MlflowException(
#     294         f"API request to {url} failed with timeout exception {to}."
#     295         " To increase the timeout, set the environment variable "
#     296         f"{MLFLOW_HTTP_REQUEST_TIMEOUT!s} to a larger value."
#     297     ) from to
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/mlflow/utils/request_utils.py:282, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     279 env_value = os.environ.get("MLFLOW_ALLOW_HTTP_REDIRECTS", "true").lower() in ["true", "1"]
#     280 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 282 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/requests/sessions.py:592, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587 send_kwargs = {
#     588     "timeout": timeout,
#     589     "allow_redirects": allow_redirects,
#     590 }
#     591 send_kwargs.update(settings)
# --> 592 resp = self.send(prep, **send_kwargs)
#     594 return resp
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/requests/sessions.py:706, in Session.send(self, request, **kwargs)
#     703 start = preferred_clock()
#     705 # Send the request
# --> 706 r = adapter.send(request, **kwargs)
#     708 # Total elapsed time of the request (approximately)
#     709 elapsed = preferred_clock() - start
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/requests/adapters.py:645, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     642     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     644 try:
# --> 645     resp = conn.urlopen(
#     646         method=request.method,
#     647         url=url,
#     648         body=request.body,
#     649         headers=request.headers,
#     650         redirect=False,
#     651         assert_same_host=False,
#     652         preload_content=False,
#     653         decode_content=False,
#     654         retries=self.max_retries,
#     655         timeout=timeout,
#     656         chunked=chunked,
#     657     )
#     659 except (ProtocolError, OSError) as err:
#     660     raise ConnectionError(err, request=request)
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/urllib3/connection.py:759, in HTTPSConnection.connect(self)
#     757 try:
#     758     sock: socket.socket | ssl.SSLSocket
# --> 759     self.sock = sock = self._new_conn()
#     760     server_hostname: str = self.host
#     761     tls_in_tls = False
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/urllib3/connection.py:204, in HTTPConnection._new_conn(self)
#     199 """Establish a socket connection and set nodelay settings on it.
#     200
#     201 :return: New socket connection.
#     202 """
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#     211     raise NameResolutionError(self.host, self, e) from e
#
# File ~/Documents/MLSN/Portfolio-Optimization-Lib/.venv/lib/python3.12/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %% [markdown]
# ## 12. Inspect Results

# %%
print("Top-level metrics:")
for key, value in sorted(result.metrics.items()):
    print(f"  {key}: {value:.6f}")
 
print("\nArtifact paths:")
for key, value in artifact_paths.items():
    print(f"  {key}: {value}")
 
display(result.nav.tail().to_frame("nav"))
display(result.returns.tail().to_frame("returns"))
display(result.turnover.tail().to_frame("turnover"))
# Out:
# Top-level metrics:
#   annual_excess_return_vs_benchmark: -0.073718
#   annual_return: 0.034594
#   annual_volatility: 0.185443
#   average_turnover: 0.170140
#   benchmark_annual_return: 0.108312
#   benchmark_annual_volatility: 0.179691
#   benchmark_max_drawdown: -0.244964
#   benchmark_sharpe: 0.602767
#   benchmark_total_return: 0.507582
#   calmar: 0.140425
#   evaluation_trading_days: 1003.000000
#   evaluation_years: 3.991786
#   excess_return_vs_benchmark: -0.362178
#   max_drawdown: -0.246352
#   sharpe: 0.186548
#   sharpe_vs_benchmark: -0.416219
#   sortino: 0.272985
#   total_return: 0.145404
#
# Artifact paths:
#   weights: /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/runs/autoencoder_downstream/weights.parquet
#   nav: /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/runs/autoencoder_downstream/nav.parquet
#   returns: /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/runs/autoencoder_downstream/returns.parquet
#   turnover: /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/runs/autoencoder_downstream/turnover.parquet
#   benchmarks: /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/runs/autoencoder_downstream/benchmarks.parquet
#   metrics: /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/runs/autoencoder_downstream/metrics.json
#   metrics_table: /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/runs/autoencoder_downstream/metrics_table.parquet
#   quantstats_report: /Users/hannahlee/Documents/MLSN/Portfolio-Optimization-Lib/runs/autoencoder_downstream/quantstats.html
#                    nav
# 2025-12-24  115.491847
# 2025-12-26  115.518759
# 2025-12-29  115.381307
# 2025-12-30  115.343811
# 2025-12-31  114.425949
#              returns
# 2025-12-24  0.004345
# 2025-12-26  0.000233
# 2025-12-29 -0.001190
# 2025-12-30 -0.000325
# 2025-12-31 -0.007958
#             turnover
# date
# 2025-12-17  0.155949
# 2025-12-18  0.145064
# 2025-12-19  0.345486
# 2025-12-22  0.265839
# 2025-12-23  0.138535

# %%
# ---------------------------------------------------------------------
# Final validation cell.
# ---------------------------------------------------------------------
# These checks are intentionally simple. They are the kind of sanity checks
# you want at the end of a notebook before you trust the output.

# In plain English:
# “Make sure nothing is broken before calling it done.”

# ---------------------------------------------------------------------

assert {"total_return", "annual_return", "sharpe", "max_drawdown"}.issubset(result.metrics)
assert validated_weights.index.is_monotonic_increasing
assert (validated_weights.sum(axis=1).round(6) == 1.0).all()
assert Path(artifact_paths["quantstats_report"]).exists()
assert {"date", "ticker", "horizon", "expected_return"}.issubset(predictions.columns)
assert predictions["uncertainty"].nunique() > 1, "uncertainty must be per-asset, not a scalar"
assert predictions["expected_alpha"].nunique() > 1, "expected_alpha must differ from expected_return"
print("End-to-end autoencoder workflow validated successfully.")
# Out:
# End-to-end autoencoder workflow validated successfully.
